# %%
# Import the libraries we'll use below.
import os 
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns  # for nicer plots
sns.set(style="darkgrid")  # default style

import tensorflow as tf
from tensorflow import keras
from keras import metrics
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
import importlib
import utilities
importlib.reload(utilities)
from utilities import *

# %%
folderPath = r"C:\Users\grays\OneDrive\Berkeley DS\Courses\207 ML\Final Project\Zillow Dataset"

# %%
answers_df = pd.read_csv(
            os.path.join(folderPath, "train_2016_v2.csv"),
            parse_dates=["transactiondate"],
        )
answers_df
# Out:
#        parcelid  logerror transactiondate
# 0      11016594    0.0276      2016-01-01
# 1      14366692   -0.1684      2016-01-01
# 2      12098116   -0.0040      2016-01-01
# 3      12643413    0.0218      2016-01-02
# 4      14432541   -0.0050      2016-01-02
# ...         ...       ...             ...
# 90270  10774160   -0.0356      2016-12-30
# 90271  12046695    0.0070      2016-12-30
# 90272  12995401   -0.2679      2016-12-30
# 90273  11402105    0.0602      2016-12-30
# 90274  12566293    0.4207      2016-12-30
#
# [90275 rows x 3 columns]

# %%
features_df = pd.read_csv(os.path.join(folderPath, "properties_2016.csv"))
features_df
# Out:
# C:\Users\grays\AppData\Local\Temp\ipykernel_7536\1691237959.py:1: DtypeWarning: Columns (22,32,34,49,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   features_df = pd.read_csv(os.path.join(folderPath, "properties_2016.csv"))
#           parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 0         10754147                    NaN                       NaN
# 1         10759547                    NaN                       NaN
# 2         10843547                    NaN                       NaN
# 3         10859147                    NaN                       NaN
# 4         10879947                    NaN                       NaN
# ...            ...                    ...                       ...
# 2985212  168176230                    NaN                       NaN
# 2985213   14273630                    NaN                       NaN
# 2985214  168040630                    NaN                       NaN
# ...

# %%
train_df = pd.merge(answers_df, features_df, on='parcelid', how='left')
train_df
# Out:
#        parcelid  logerror transactiondate  airconditioningtypeid  \
# 0      11016594    0.0276      2016-01-01                    1.0
# 1      14366692   -0.1684      2016-01-01                    NaN
# 2      12098116   -0.0040      2016-01-01                    1.0
# 3      12643413    0.0218      2016-01-02                    1.0
# 4      14432541   -0.0050      2016-01-02                    NaN
# ...         ...       ...             ...                    ...
# 90270  10774160   -0.0356      2016-12-30                    1.0
# 90271  12046695    0.0070      2016-12-30                    NaN
# 90272  12995401   -0.2679      2016-12-30                    NaN
# 90273  11402105    0.0602      2016-12-30                    NaN
# 90274  12566293    0.4207      2016-12-30                    NaN
#
#        architecturalstyletypeid  basementsqft  bathroomcnt  bedroomcnt  \
# 0                           NaN           NaN          2.0         3.0
# ...
